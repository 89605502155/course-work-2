# %%
from gzip import open # NB: overrides standard open()
import pickle as pkl
import tensorly as tl
from tensorly.base import tensor_to_vec,  partial_tensor_to_vec
import numpy as np
import pandas as pd
import warnings 
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split

warnings.simplefilter('ignore') # отключим предупреждения Anaconda
Xdata_numpy = pkl.load(open('C:/Users/admin/Desktop/88/X.pkl.gz', 'rb'))
Ydata = pkl.load(open('C:/Users/admin/Desktop/88/y.pkl.gz', 'rb'))

print(type(Xdata_numpy["X"]))

#делим набор на обучающий и тестовый
X_train, X_test, y_train, y_test = train_test_split(
     Xdata_numpy["X"], Ydata, test_size=0.1428 
)

print( y_train.shape)
# прописываем класс регрессии
from sklearn.base import BaseEstimator
from sklearn.metrics import r2_score
from tensorly.regression.kruskal_regression import KruskalRegressor

class WrappedKruskalRegressor(BaseEstimator):
	def __init__(self, weight_rank = 1, tol = 1e-6, reg_W = 1, n_iter_max = 100):
		self.weight_rank = weight_rank
		self.tol = tol
		self.reg_W = reg_W
		self.n_iter_max = n_iter_max
	
	def fit(self, X, y = None):
		self._model = KruskalRegressor(self.weight_rank, self.tol, self.reg_W, self.n_iter_max)
		self._model.fit(X, y)
		if self._model.n_iterations_ == self.n_iter_max:
			raise Exception('{} did not converge'.format(self))
		return self
	
	def predict(self, X):
		return self._model.predict(X)
	
	def score(self, X, y):
		return r2_score(y, self.predict(X))


#начинаем применять

from sklearn.model_selection import GridSearchCV
regressioModel=WrappedKruskalRegressor()
parametrsNames={'n_iter_max': [10000],
                'reg_W': range(1,3),
                'tol': [1e-06],
                'weight_rank': range(1,3)
               }

gridCought=GridSearchCV(regressioModel, parametrsNames, cv=5)
gridCought.fit(X_train,y_train.iloc[:,0])
predictors=gridCought.predict(X_test)

print(gridCought.best_params_)
# Out:
# <class 'numpy.ndarray'>
# (30, 3)
#
# Converged in 2395 iterations
#
# Converged in 1615 iterations
#
# Converged in 56 iterations
#
# Converged in 2965 iterations
#
# Converged in 1172 iterations
#
# Converged in 3847 iterations
#
# Converged in 308 iterations
#
# Converged in 144 iterations
#
# Converged in 1865 iterations
#
# Converged in 576 iterations
#
# Converged in 2325 iterations
#
# Converged in 2643 iterations
#
# Converged in 2068 iterations
#
# Converged in 918 iterations
#
# Converged in 2252 iterations
#
# Converged in 3353 iterations
#
# Converged in 203 iterations
#
# Converged in 289 iterations
#
# Converged in 268 iterations
#
# Converged in 210 iterations
#
# Converged in 226 iterations
# {'n_iter_max': 10000, 'reg_W': 2, 'tol': 1e-06, 'weight_rank': 2}

# %%
print("Правильность на тестовом наборе: {:.2f}".format(gridCought.score(X_test, y_test)))
